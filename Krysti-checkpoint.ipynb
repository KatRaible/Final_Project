# %%
import numpy as np
import pandas as pd
import statistics

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

import sqlalchemy
from sqlalchemy import create_engine, text

import psycopg2

# %%
connection_url = 'postgresql://root:u2YJR7TNLPpF1THVLsPS@database-1.cd0asuee8tgm.us-east-2.rds.amazonaws.com:5432/postgres'
engine = create_engine(connection_url)

query = text('SELECT * FROM darwin')  
darwin_df = pd.read_sql(query, engine)

# %%
darwin_df.head()
# Out:
#           route_id unique_id service_start_date update_origin train_platform  \
# 0  202403217105805    G05805         2024-03-21         Trust         WCLIFF
# 1  202403217105805    G05805         2024-03-21         Trust        CHLKWEL
# 2  202403217105798    G05798         2024-03-21           CIS        BARKING
# 3  202403217604342    L04342         2024-03-21            TD        SURREYQ
# 4  202403218731849    W31849         2024-03-21          None           GIDB
#
#   working_time_pass working_time_arrival working_time_departure  \
# 0              None             23:38:00               23:38:30
# 1              None             23:40:30               23:41:00
# 2              None             23:39:00               23:39:30
# 3              None             23:29:30               23:30:30
# 4              None             23:38:30               23:39:00
#
#   planned_time_arrival planned_time_departure  ... platform train_length  \
# 0             23:38:00               23:38:00  ...        1          8.0
# 1             23:41:00               23:41:00  ...        1          8.0
# 2             23:39:00               23:39:00  ...        5          4.0
# 3             23:30:00               23:30:00  ...        2          NaN
# 4             23:39:00               23:39:00  ...        2          3.0
#
#   estimated_time  source actual_time actual_time_class is_delayed_arrival  \
# 0           None    None        None              None              False
# 1           None    None        None              None              False
# 2           None    None        None              None              False
# 3           None    None        None              None              False
# 4           None    None        None              None              False
#
#   is_delayed_departure  source_instance  estimated_time_minutes
# 0                False             None                    None
# 1                False             None                    None
# 2                False             None                    None
# 3                False             None                    None
# 4                False             None                    None
#
# [5 rows x 22 columns]

# %%
darwin_df.shape
# Out:
# (1326, 22)

# %%
# drop unnecessary columns

darwin_df.drop(columns=['working_time_pass', 'estimated_time', 'source', 'actual_time', 'actual_time_class', 'source_instance', 'estimated_time_minutes'], inplace=True)

# %%
darwin_df.head()
# Out:
#           route_id unique_id service_start_date update_origin train_platform  \
# 0  202403217105805    G05805         2024-03-21         Trust         WCLIFF
# 1  202403217105805    G05805         2024-03-21         Trust        CHLKWEL
# 2  202403217105798    G05798         2024-03-21           CIS        BARKING
# 3  202403217604342    L04342         2024-03-21            TD        SURREYQ
# 4  202403218731849    W31849         2024-03-21          None           GIDB
#
#   working_time_arrival working_time_departure planned_time_arrival  \
# 0             23:38:00               23:38:30             23:38:00
# 1             23:40:30               23:41:00             23:41:00
# 2             23:39:00               23:39:30             23:39:00
# 3             23:29:30               23:30:30             23:30:00
# 4             23:38:30               23:39:00             23:39:00
#
#   planned_time_departure actual_arrival_time actual_departure_time platform  \
# 0               23:38:00                None                  None        1
# 1               23:41:00            23:41:00              23:41:00        1
# 2               23:39:00            23:39:00              23:39:00        5
# 3               23:30:00                None              23:38:00        2
# 4               23:39:00            23:39:00              23:39:00        2
#
#    train_length  is_delayed_arrival  is_delayed_departure
# 0           8.0               False                 False
# 1           8.0               False                 False
# 2           4.0               False                 False
# 3           NaN               False                 False
# 4           3.0               False                 False

# %%
# read station name reference table

rail_names = pd.read_csv("RailReferences.csv")
rail_names.head()
# Out:
#       AtcoCode TiplocCode CrsCode                      StationName  \
# 0  9100PENZNCE    PENZNCE     PNZ            Penzance Rail Station
# 1   9100STIVES     STIVES     SIV  St Ives (Cornwall) Rail Station
# 2  9100CARBISB    CARBISB     CBB          Carbis Bay Rail Station
# 3   9100STERTH     STERTH     SER             St Erth Rail Station
# 4  9100LELANTS    LELANTS     LTS     Lelant Saltings Rail Station
#
#    StationNameLang GridType  Easting  Northing     CreationDateTime  \
# 0              NaN        U   147588     30599  2003-11-04T00:00:00
# 1              NaN        U   151947     40127  2005-04-04T00:00:00
# 2              NaN        U   152930     38745  2003-11-04T00:00:00
# 3              NaN        U   154150     35730  2003-11-04T00:00:00
# 4              NaN        U   154430     36640  2003-11-04T00:00:00
#
#   ModificationDateTime  RevisionNumber Modification
# 0  2011-09-30T14:47:28               2          rev
# 1  2011-09-30T14:47:28               4          rev
# 2  2011-09-30T14:47:28               5          rev
# 3  2007-02-13T17:06:21               3          rev
# 4  2011-09-30T14:47:28               2          rev

# %%
# Remove unnecessary columns from staion name reference table

rail_names = rail_names.loc[:, rail_names.columns.intersection(['TiplocCode','StationName'])]
rail_names.head()
# Out:
#   TiplocCode                      StationName
# 0    PENZNCE            Penzance Rail Station
# 1     STIVES  St Ives (Cornwall) Rail Station
# 2    CARBISB          Carbis Bay Rail Station
# 3     STERTH             St Erth Rail Station
# 4    LELANTS     Lelant Saltings Rail Station

# %%
darwin_df = pd.merge(darwin_df, rail_names, how='inner', left_on='train_platform', right_on='TiplocCode')
darwin_df.head()
# Out:
#           route_id unique_id service_start_date update_origin train_platform  \
# 0  202403217105805    G05805         2024-03-21         Trust         WCLIFF
# 1  202403217105805    G05805         2024-03-21         Trust        CHLKWEL
# 2  202403217105798    G05798         2024-03-21           CIS        BARKING
# 3  202403217604342    L04342         2024-03-21            TD        SURREYQ
# 4  202403218731849    W31849         2024-03-21          None           GIDB
#
#   working_time_arrival working_time_departure planned_time_arrival  \
# 0             23:38:00               23:38:30             23:38:00
# 1             23:40:30               23:41:00             23:41:00
# 2             23:39:00               23:39:30             23:39:00
# 3             23:29:30               23:30:30             23:30:00
# 4             23:38:30               23:39:00             23:39:00
#
#   planned_time_departure actual_arrival_time actual_departure_time platform  \
# 0               23:38:00                None                  None        1
# 1               23:41:00            23:41:00              23:41:00        1
# 2               23:39:00            23:39:00              23:39:00        5
# 3               23:30:00                None              23:38:00        2
# 4               23:39:00            23:39:00              23:39:00        2
#
#    train_length  is_delayed_arrival  is_delayed_departure TiplocCode  \
# 0           8.0               False                 False     WCLIFF
# 1           8.0               False                 False    CHLKWEL
# 2           4.0               False                 False    BARKING
# 3           NaN               False                 False    SURREYQ
# 4           3.0               False                 False       GIDB
#
#                      StationName
# 0  Westcliff-on-Sea Rail Station
# 1         Chalkwell Rail Station
# 2           Barking Rail Station
# 3      Surrey Quays Rail Station
# 4      Guide Bridge Rail Station

# %%
# drop extra station code name columns

# darwin_df.drop(columns=['train_platform', 'TiplocCode'], inplace=True)

# %%
origin_df = darwin_df.dropna(subset=['update_origin'])
origin_df.head()
# Out:
#            route_id unique_id service_start_date update_origin train_platform  \
# 0   202403217105805    G05805         2024-03-21         Trust         WCLIFF
# 1   202403217105805    G05805         2024-03-21         Trust        CHLKWEL
# 2   202403217105798    G05798         2024-03-21           CIS        BARKING
# 3   202403217604342    L04342         2024-03-21            TD        SURREYQ
# 11  202403217105804    G05804         2024-03-21         Trust        UPMNSTR
#
#    working_time_arrival working_time_departure planned_time_arrival  \
# 0              23:38:00               23:38:30             23:38:00
# 1              23:40:30               23:41:00             23:41:00
# 2              23:39:00               23:39:30             23:39:00
# 3              23:29:30               23:30:30             23:30:00
# 11             23:37:30               23:38:00             23:38:00
#
#    planned_time_departure actual_arrival_time actual_departure_time platform  \
# 0                23:38:00                None                  None        1
# 1                23:41:00            23:41:00              23:41:00        1
# 2                23:39:00            23:39:00              23:39:00        5
# 3                23:30:00                None              23:38:00        2
# 11               23:38:00                None              23:38:00        1
#
#     train_length  is_delayed_arrival  is_delayed_departure TiplocCode  \
# 0            8.0               False                 False     WCLIFF
# 1            8.0               False                 False    CHLKWEL
# 2            4.0               False                 False    BARKING
# 3            NaN               False                 False    SURREYQ
# 11           4.0               False                 False    UPMNSTR
#
#                       StationName
# 0   Westcliff-on-Sea Rail Station
# 1          Chalkwell Rail Station
# 2            Barking Rail Station
# 3       Surrey Quays Rail Station
# 11         Upminster Rail Station

# %%
origin_df.update_origin.unique()
# Out:
# array(['Trust', 'CIS', 'TD', 'Darwin'], dtype=object)

# %%
trust_origin = origin_df[origin_df.update_origin == 'Trust']
CIS_origin = origin_df[origin_df.update_origin == 'CIS']
TD_origin = origin_df[origin_df.update_origin == 'TD']
darwin_origin = origin_df[origin_df.update_origin == 'Darwin']

# %%
print('Trust: ', trust_origin.shape)
print('CIS: ', CIS_origin.shape)
print('TD: ', TD_origin.shape)
print('Darwin: ', darwin_origin.shape)
# Out:
# Trust:  (78, 17)
# CIS:  (237, 17)
# TD:  (605, 17)
# Darwin:  (246, 17)

# %%
trust_null_count = trust_origin.isnull().sum().sum()
CIS_null_count = CIS_origin.isnull().sum().sum()
TD_null_count = TD_origin.isnull().sum().sum()
darwin_null_count = darwin_origin.isnull().sum().sum()

print('Trust: ', trust_null_count)
print('CIS: ', CIS_null_count)
print('TD: ', TD_null_count)
print('Darwin: ', darwin_null_count)
# Out:
# Trust:  103
# CIS:  173
# TD:  816
# Darwin:  463

# %%
trust_cell_count = 78 * 15
CIS_cell_count = 237 *15
TD_cell_count = 605 *15
darwin_cell_count = 246 *15

trust_null_by_df = trust_null_count / trust_cell_count
CIS_null_by_df = CIS_null_count / CIS_cell_count
TD_null_by_df = TD_null_count / TD_cell_count
darwin_null_by_df = darwin_null_count / darwin_cell_count

trust_null_by_event = trust_null_count / 78
CIS_null_by_event = CIS_null_count / 237
TD_null_by_event = TD_null_count / 605
darwin_null_by_event = darwin_null_count / 246

# %%
data = [['Trust', trust_null_count, trust_null_by_df, trust_null_by_event], ['CIS', CIS_null_count, CIS_null_by_df, CIS_null_by_event], ['TD', TD_null_count, TD_null_by_df, TD_null_by_event], ['Darwin', darwin_null_count, darwin_null_by_df, darwin_null_by_event]]

origin_reliability_df = pd.DataFrame(data, columns=['Update Origin', 'Total Null Values', 'DataFrame Null Proportion', 'Event Null Proportion'])
origin_reliability_df
# Out:
#   Update Origin  Total Null Values  DataFrame Null Proportion  \
# 0         Trust                103                   0.088034
# 1           CIS                173                   0.048664
# 2            TD                816                   0.089917
# 3        Darwin                463                   0.125474
#
#    Event Null Proportion
# 0               1.320513
# 1               0.729958
# 2               1.348760
# 3               1.882114

# %%
sns.barplot(origin_reliability_df, x='Update Origin', y='DataFrame Null Proportion', color='lightseagreen')

plt.title('Proportion of Missing Data by Update Origin Source')
plt.ylabel('Proportion of Null Data')
# Out:
# Text(0, 0.5, 'Proportion of Null Data')

# %%
sns.barplot(origin_reliability_df, x='Update Origin', y='Event Null Proportion',color='lightseagreen')
# Out:
# <Axes: xlabel='Update Origin', ylabel='Event Null Proportion'>

# %%
downtime_df = darwin_df.dropna(subset=['actual_arrival_time', 'actual_departure_time'])

downtime_df = downtime_df.loc[:, downtime_df.columns.intersection(['actual_arrival_time','actual_departure_time', 'is_delayed_arrival'])]

downtime_df.head()
# Out:
#   actual_arrival_time actual_departure_time  is_delayed_arrival
# 1            23:41:00              23:41:00               False
# 2            23:39:00              23:39:00               False
# 4            23:39:00              23:39:00               False
# 5            23:42:00              23:42:00               False
# 6            23:44:00              23:44:00               False

# %%
downtime_df['actual_arrival_time'] = pd.to_datetime(downtime_df['actual_arrival_time'], format='%H:%M:%S')
downtime_df['actual_departure_time'] = pd.to_datetime(downtime_df['actual_departure_time'], format='%H:%M:%S')

downtime_df.head()
# Out:
#   actual_arrival_time actual_departure_time  is_delayed_arrival
# 1 1900-01-01 23:41:00   1900-01-01 23:41:00               False
# 2 1900-01-01 23:39:00   1900-01-01 23:39:00               False
# 4 1900-01-01 23:39:00   1900-01-01 23:39:00               False
# 5 1900-01-01 23:42:00   1900-01-01 23:42:00               False
# 6 1900-01-01 23:44:00   1900-01-01 23:44:00               False

# %%
downtime_df['time_diff'] = downtime_df['actual_departure_time'] - downtime_df['actual_arrival_time']

downtime_df.head()
# Out:
#   actual_arrival_time actual_departure_time  is_delayed_arrival time_diff
# 1 1900-01-01 23:41:00   1900-01-01 23:41:00               False    0 days
# 2 1900-01-01 23:39:00   1900-01-01 23:39:00               False    0 days
# 4 1900-01-01 23:39:00   1900-01-01 23:39:00               False    0 days
# 5 1900-01-01 23:42:00   1900-01-01 23:42:00               False    0 days
# 6 1900-01-01 23:44:00   1900-01-01 23:44:00               False    0 days

# %%
downtime_df['minutes_difference'] = downtime_df['time_diff'].dt.total_seconds() / 60
downtime_df['seconds_difference'] = downtime_df['time_diff'].dt.seconds

downtime_df.head()
# Out:
#   actual_arrival_time actual_departure_time  is_delayed_arrival time_diff  \
# 1 1900-01-01 23:41:00   1900-01-01 23:41:00               False    0 days
# 2 1900-01-01 23:39:00   1900-01-01 23:39:00               False    0 days
# 4 1900-01-01 23:39:00   1900-01-01 23:39:00               False    0 days
# 5 1900-01-01 23:42:00   1900-01-01 23:42:00               False    0 days
# 6 1900-01-01 23:44:00   1900-01-01 23:44:00               False    0 days
#
#    minutes_difference  seconds_difference
# 1                 0.0                   0
# 2                 0.0                   0
# 4                 0.0                   0
# 5                 0.0                   0
# 6                 0.0                   0

# %%
downtime_df.seconds_difference.unique()
# Out:
# array([   0,   60,  120,  300,  660,  420, 2580,  180, 1320,  540, 3420,
#         240,  720,  360, 2520])

# %%
downtime_df.minutes_difference.unique()
# Out:
# array([ 0.,  1.,  2.,  5., 11.,  7., 43.,  3., 22.,  9., 57.,  4., 12.,
#         6., 42.])

# %%
minutes_counts = downtime_df.minutes_difference.value_counts()

top_downtime = minutes_counts.head(3)

top_downtime
# Out:
# minutes_difference
# 1.0    431
# 0.0    415
# 2.0     35
# Name: count, dtype: int64

# %%
plt.pie(top_downtime, autopct='%1.1f%%', startangle=90, labels=None, colors=['lightseagreen', 'lightcoral', 'darksalmon', 'teal', 'cornflowerblue'] )
plt.title('Average Time in Minutes Between Arrival and Departure')
plt.legend(labels=['1 Minute', '0 Minutes', '2 Minutes'], bbox_to_anchor=(2, 0.5))

# %%
sns.histplot(data=downtime_df, x='minutes_difference')
plt.title('Minutes Spent at Station Between Arrival and Departure')
plt.xlabel('Minutes')
plt.xlim(0, 10)
